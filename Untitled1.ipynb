# %% [markdown]
# <a href="https://colab.research.google.com/github/manav88/ML-Project/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
pd.set_option('display.max_rows',1000)

# %%
df=pd.read_csv('/content/COVID_dataset_v0.csv')

# %%
dff=df.groupby('city')

dff.first()
# Out:
#                         unitid   FIPS              county_name state  \
# city
# Ada                     204635  39065            Hardin County    OH
# Albany                  196060  36001            Albany County    NY
# Amherst                 166629  25015         Hampshire County    MA
# Ann Arbor               170976  26161         Washtenaw County    MI
# Athens                  139959  13059            Clarke County    GA
# Atlanta                 139658  13089            DeKalb County    GA
# Austin                  228778  48453            Travis County    TX
# Baltimore               162928  24510           Baltimore city    MD
# Baton Rouge             159391  22033  East Baton Rouge Parish    LA
# Berkeley                110635   6001           Alameda County    CA
# Bethlehem               213543  42095       Northampton County    PA
# Blacksburg              233921  51121        Montgomery County    VA
# ...

# %%
df['city'].unique()
# Out:
# array(['Fayetteville', 'San Luis Obispo', 'Berkeley', 'Los Angeles',
#        'La Jolla', 'Boulder', 'Denver', 'Grand Junction', 'New London',
#        'Storrs', 'West Haven', 'Hartford', 'Middletown', 'Washington',
#        'Tallahassee', 'Gainesville', 'Coral Gables', 'Atlanta', 'Athens',
#        'Peoria', 'Charleston', 'Chicago', 'Champaign', 'Dekalb',
#        'Evanston', 'Muncie', 'Indianapolis', 'Notre Dame', 'Emporia',
#        'Manhattan', 'Wichita', 'Lexington', 'Louisville', 'Baton Rouge',
#        'New Orleans', 'Lewiston', 'Baltimore', 'Towson', 'Chestnut Hill',
#        'Boston', 'Worcester', 'Cambridge', 'Amherst', 'Medford',
#        'Williamstown', 'Rochester Hills', 'Ann Arbor', 'Marquette',
#        'Minneapolis', 'Duluth', 'Mississippi State', 'Saint Louis',
#        'Lincoln', 'Hanover', 'Camden', 'New York', 'Ithaca', 'Troy',
#        'Albany', 'Vestal', 'Buffalo', 'Stony Brook', 'Syracuse',
#        'Poughkeepsie', 'Boone', 'Durham', 'Elon', 'Chapel Hill',
# ...

# %%
# xpoints = df('city')
# ypoints = df('TotalCount')

df.plot(x='city',y='TotalCount')
plt.show()

# %%
df.describe()
# Out:
#               unitid          FIPS     latitude    longitude         week  \
# count    1130.000000   1130.000000  1130.000000  1130.000000  1130.000000
# mean   182157.344248  30157.324779    39.326055   -84.021281  3160.638053
# std     36815.520544  14215.467107     4.025146    11.909187     2.823563
# min    106397.000000   5143.000000    25.721260  -122.260463  3156.000000
# 25%    155025.000000  18141.000000    37.269489   -88.766428  3158.000000
# 50%    182670.000000  29510.000000    40.039388   -80.549728  3161.000000
# 75%    213543.000000  42027.000000    42.050356   -75.305207  3163.000000
# max    243780.000000  55079.000000    47.921654   -70.203333  3165.000000
#
#        admission_rate  number_students     TotalCount  TotalCountWeekly  \
# count     1130.000000      1130.000000    1130.000000       1130.000000
# mean         0.482847     14015.532743   34808.481416       4341.392920
# std          0.257576     11236.392030   67725.163161       7737.110434
# ...

# %%
city_counts = df['city'].value_counts()

# Print the number of unique cities
num_cities = len(city_counts)
print("Number of unique cities:", num_cities)

# Print the city counts
print("City counts:")
print(city_counts)
# Out:
# Number of unique cities: 108
# City counts:
# New York                  20
# Pittsburgh                20
# Lexington                 20
# Chicago                   20
# Philadelphia              20
# Cambridge                 20
# Worcester                 20
# Boston                    20
# Baltimore                 20
# Fayetteville              10
# Raleigh                   10
# Columbus                  10
# Ada                       10
# Hiram                     10
# Cleveland                 10
# Grand Forks               10
# Elon                      10
# Chapel Hill               10
# Norman                    10
# Durham                    10
# Syracuse                  10
# Stony Brook               10
# Buffalo                   10
# Vestal                    10
# Albany                    10
# Ithaca                    10
# Stillwater                10
# Lewisburg                 10
# Bryn Mawr                 10
# Middlebury                10
# ...

# %%
df.head()
# Out:
#    unitid  FIPS        county_name          city state    zip   latitude  \
# 0  106397  5143  Washington County  Fayetteville    AR  72701  36.070009
# 1  106397  5143  Washington County  Fayetteville    AR  72701  36.070009
# 2  106397  5143  Washington County  Fayetteville    AR  72701  36.070009
# 3  106397  5143  Washington County  Fayetteville    AR  72701  36.070009
# 4  106397  5143  Washington County  Fayetteville    AR  72701  36.070009
#
#    longitude       date  week  admission_rate  number_students  TotalCount  \
# 0 -94.176981  13sep2020  3156          0.7747            23121        4571
# 1 -94.176981  20sep2020  3157          0.7747            23121        5766
# 2 -94.176981  27sep2020  3158          0.7747            23121        6669
# 3 -94.176981  04oct2020  3159          0.7747            23121        7796
# 4 -94.176981  11oct2020  3160          0.7747            23121        8922
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   unitid                        1130 non-null   int64
#  1   FIPS                          1130 non-null   int64
#  2   county_name                   1130 non-null   object
#  3   city                          1130 non-null   object
#  4   state                         1130 non-null   object
#  5   zip                           1130 non-null   object
#  6   latitude                      1130 non-null   float64
#  7   longitude                     1130 non-null   float64
#  8   date                          1130 non-null   object
#  9   week                          1130 non-null   int64
#  10  admission_rate                1130 non-null   float64
#  11  number_students               1130 non-null   int64
# ...

# %%
df['city'].corr
# Out:
# <bound method Series.corr of 0         Fayetteville
# 1         Fayetteville
# 2         Fayetteville
# 3         Fayetteville
# 4         Fayetteville
#              ...
# 1125    West Lafayette
# 1126    West Lafayette
# 1127    West Lafayette
# 1128    West Lafayette
# 1129    West Lafayette
# Name: city, Length: 1130, dtype: object>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-62b7bfcb7dc8> in <cell line: 1>()
# ----> 1 dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)
#       2
#       3 # displaying heatmap
#       4 plt.show()
#
# NameError: name 'sb' is not defined

# %%
print(df.corr())
# Out:
#                                 unitid      FIPS  latitude  longitude  \
# unitid                        1.000000  0.917307  0.069762   0.209365
# FIPS                          0.917307  1.000000  0.074372   0.293077
# latitude                      0.069762  0.074372  1.000000   0.278921
# longitude                     0.209365  0.293077  0.278921   1.000000
# week                          0.003633  0.006395 -0.005625   0.006162
# admission_rate               -0.000570  0.039495  0.068516  -0.186016
# number_students              -0.029953 -0.048696 -0.346169  -0.303839
# TotalCount                   -0.103868 -0.099132  0.050970   0.088164
# TotalCountWeekly             -0.090936 -0.094472  0.085179   0.145489
# TotalConfirmedPositive        0.011510  0.011393 -0.262199  -0.227052
# TotalConfirmedPositiveWeekly  0.066728  0.027210 -0.157184  -0.122736
# TotalPositivityRate          -0.034097 -0.015782 -0.058580  -0.201690
# ...

# %%
df_trans=pd.get_dummies(df)

# %%
x=df_trans.drop(['unitid','latitude','longitude','FIPS','TotalPositivityRate'],axis=1)
y=df_trans['TotalPositivityRate']
features=x.columns

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import  LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
s=StandardScaler()
X=s.fit_transform(x)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y)

# %%
lin=LinearRegression()
lin=lin.fit(X_train,Y_train)
y_pred=lin.predict(X_test)

# %%
model_eval=pd.DataFrame(index=['KNN','MLR'],columns=['RMSE'])

# %%
model_eval.loc['MLR','RMSE']=np.sqrt(mean_squared_error(y_pred,Y_test))
model_eval
# Out:
#          RMSE
# KNN       NaN
# MLR  1.172132

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(Y_test, y_pred), 2))
print("Mean squared error =", round(sm.mean_squared_error(Y_test, y_pred), 2))
print("Median absolute error =", round(sm.median_absolute_error(Y_test, y_pred), 2))
print("Explain variance score =", round(sm.explained_variance_score(Y_test, y_pred), 2))
print("R2 score =", round(sm.r2_score(Y_test, y_pred), 2))
# Out:
# Mean absolute error = 0.66
# Mean squared error = 1.37
# Median absolute error = 0.36
# Explain variance score = 0.94
# R2 score = 0.94

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor

modelDTR = DecisionTreeRegressor(max_depth=3)
modelDTR.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
modelDTR.score(X_train, Y_train)
# Out:
# 0.7638084280735198

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
y_predDTR=modelDTR.predict(X_test)
r2_score(Y_test,y_predDTR)
# Out:
# 0.6732247753537092

# %%
from xgboost import XGBRegressor
modelXGB = XGBRegressor()
modelXGB.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
modelXGB.score(X_train, Y_train)
# Out:
# 0.9999569930250032

# %%
y_predXGB=modelXGB.predict(X_test)
r2_score(Y_test,y_predXGB)
# Out:
# 0.9713039675455546
